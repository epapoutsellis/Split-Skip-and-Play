# %%
# install and wait to restart
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:12
# 🔁 Restarting kernel...

# %%
# !conda install -y -c conda-forge -c ccpi python "numpy<2.0" "zarr<3" \
  cmake scipy six cython numba pillow scikit-learn dask cvxpy pywavelets astra-toolbox tqdm
# Out:
# Channels:
#  - conda-forge
#  - ccpi
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - astra-toolbox
#     - cmake
#     - cvxpy
#     - cython
#     - dask
#     - numba
#     - numpy[version='<2.0']
#     - pillow
#     - python
#     - pywavelets
#     - scikit-learn
#     - scipy
#     - six
#     - tqdm
#     - zarr[version='<3']
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     asciitree-0.3.3            |             py_2           6 KB  conda-forge
#     astra-toolbox-2.3.1        |  py312hda1af2d_0         395 KB  conda-forge
#     aws-c-auth-0.9.3           |       hef928c7_0         130 KB  conda-forge
#     aws-c-cal-0.9.13           |       h2c9d079_1          55 KB  conda-forge
#     aws-c-common-0.12.6        |       hb03c661_0         234 KB  conda-forge
#     aws-c-compression-0.3.1    |       h8b1a151_9          22 KB  conda-forge
#     aws-c-event-stream-0.5.7   |       h28f887f_1          57 KB  conda-forge
#     aws-c-http-0.10.7          |       ha8fc4e3_5         219 KB  conda-forge
#     aws-c-io-0.23.3            |       hdaf4b65_5         177 KB  conda-forge
#     aws-c-mqtt-0.13.3          |      hc63082f_11         211 KB  conda-forge
#     aws-c-s3-0.11.3            |       h06ab39a_1         148 KB  conda-forge
#     aws-c-sdkutils-0.2.4       |       h8b1a151_4          58 KB  conda-forge
#     aws-checksums-0.2.7        |       h8b1a151_5          75 KB  conda-forge
#     aws-crt-cpp-0.35.4         |       h8824e59_0         399 KB  conda-forge
#     aws-sdk-cpp-1.11.606       |      h20b40b1_10         3.3 MB  conda-forge
#     azure-core-cpp-1.16.2      |       h206d751_0         341 KB  conda-forge
#     azure-identity-cpp-1.13.3  |       hed0cdb0_1         245 KB  conda-forge
#     azure-storage-blobs-cpp-12.16.0|       hdd73cc9_1         566 KB  conda-forge
#     azure-storage-common-cpp-12.12.0|       ha7a2c86_1         147 KB  conda-forge
#     azure-storage-files-datalake-cpp-12.14.0|       h52c5a47_1         295 KB  conda-forge
#     bokeh-3.8.2                |     pyhd8ed1ab_0         4.5 MB  conda-forge
#     brotli-python-1.2.0        |  py312hdb49522_1         360 KB  conda-forge
#     c-ares-1.34.6              |       hb03c661_0         203 KB  conda-forge
#     ca-certificates-2026.1.4   |       hbd8a1cb_0         143 KB  conda-forge
#     certifi-2026.1.4           |     pyhd8ed1ab_0         147 KB  conda-forge
#     cffi-2.0.0                 |  py312h460c074_1         289 KB  conda-forge
#     clarabel-0.11.1            |  py312h0ccc70a_2         926 KB  conda-forge
#     click-8.3.1                |     pyh8f84b5b_1          95 KB  conda-forge
#     cloudpickle-3.1.2          |     pyhcf101f3_1          27 KB  conda-forge
#     cmake-4.2.3                |       hc85cc9f_1        21.3 MB  conda-forge
#     conda-26.1.0               |  py312h7900ff3_0         1.2 MB  conda-forge
#     conda-libmamba-solver-25.11.0|     pyhd8ed1ab_1          56 KB  conda-forge
#     contourpy-1.3.3            |  py312h0a2e395_4         313 KB  conda-forge
#     cpp-expected-1.3.1         |       h171cf75_0          24 KB  conda-forge
#     cvxpy-1.7.5                |  py312h217f5b8_1         164 KB  conda-forge
#     cvxpy-base-1.7.5           |np2py312h0f77346_1         1.7 MB  conda-forge
#     cython-3.2.4               |  py312h68e6be4_0         3.6 MB  conda-forge
#     cytoolz-1.1.0              |  py312h4c3975b_1         579 KB  conda-forge
#     dask-2026.1.2              |     pyhcf101f3_1          11 KB  conda-forge
#     dask-core-2026.1.2         |     pyhcf101f3_0         1.0 MB  conda-forge
#     deprecated-1.3.1           |     pyhd8ed1ab_1          16 KB  conda-forge
#     distributed-2026.1.2       |     pyhcf101f3_1         825 KB  conda-forge
#     fasteners-0.19             |     pyhd8ed1ab_1          20 KB  conda-forge
#     fmt-12.1.0                 |       hff5e90c_0         193 KB  conda-forge
#     frozendict-2.4.7           |  py312h4c3975b_0          31 KB  conda-forge
#     fsspec-2026.2.0            |     pyhd8ed1ab_0         145 KB  conda-forge
#     gflags-2.2.2               |    h5888daf_1005         117 KB  conda-forge
#     glog-0.7.1                 |       hbabe93e_0         140 KB  conda-forge
#     icu-78.2                   |       h33c6efd_0        12.1 MB  conda-forge
#     importlib-metadata-8.7.0   |     pyhe01879c_1          34 KB  conda-forge
#     jinja2-3.1.6               |     pyhcf101f3_1         118 KB  conda-forge
#     joblib-1.5.3               |     pyhd8ed1ab_0         221 KB  conda-forge
#     jsonpointer-3.0.0          |     pyhcf101f3_3          14 KB  conda-forge
#     lcms2-2.18                 |       h0c24ade_0         244 KB  conda-forge
#     lerc-4.0.0                 |       h0aef613_1         258 KB  conda-forge
#     libabseil-20260107.1       | cxx17_h7b12aa8_0         1.3 MB  conda-forge
#     libarchive-3.8.5           | gpl_hc2c16d8_100         865 KB  conda-forge
#     libarrow-23.0.1            |   h2603568_0_cpu         6.2 MB  conda-forge
#     libarrow-acero-23.0.1      |   h635bf11_0_cpu         595 KB  conda-forge
#     libarrow-compute-23.0.1    |   h53684a4_0_cpu         2.9 MB  conda-forge
#     libarrow-dataset-23.0.1    |   h635bf11_0_cpu         594 KB  conda-forge
#     libarrow-substrait-23.0.1  |   hb4dd7c2_0_cpu         507 KB  conda-forge
#     libastra-2.3.1             |       hd22cb3e_2         666 KB  conda-forge
#     libblas-3.11.0             |5_h4a7cf45_openblas          18 KB  conda-forge
#     libbrotlicommon-1.2.0      |       hb03c661_1          78 KB  conda-forge
#     libbrotlidec-1.2.0         |       hb03c661_1          34 KB  conda-forge
#     libbrotlienc-1.2.0         |       hb03c661_1         291 KB  conda-forge
#     libcblas-3.11.0            |5_h0358290_openblas          18 KB  conda-forge
#     libcrc32c-1.1.2            |       h9c3ff4c_0          20 KB  conda-forge
#     libcurl-8.18.0             |       h4e3cde8_0         452 KB  conda-forge
#     libdeflate-1.25            |       h17f619e_0          72 KB  conda-forge
#     libevent-2.1.12            |       hf998b51_1         417 KB  conda-forge
#     libexpat-2.7.4             |       hecca717_0          75 KB  conda-forge
#     libffi-3.5.2               |       h3435931_0          57 KB  conda-forge
#     libfreetype-2.14.1         |       ha770c72_0           7 KB  conda-forge
#     libfreetype6-2.14.1        |       h73754d4_0         378 KB  conda-forge
#     libgcc-15.2.0              |      he0feb66_18        1017 KB  conda-forge
#     libgcc-ng-15.2.0           |      h69a702a_18          27 KB  conda-forge
#     libgfortran-15.2.0         |      h69a702a_18          27 KB  conda-forge
#     libgfortran5-15.2.0        |      h68bc16d_18         2.4 MB  conda-forge
#     libgomp-15.2.0             |      he0feb66_18         589 KB  conda-forge
#     libgoogle-cloud-2.39.0     |       h9d11ab5_1         1.2 MB  conda-forge
#     libgoogle-cloud-storage-2.39.0|       hdbdcf42_1         785 KB  conda-forge
#     libgrpc-1.78.0             |       h1d1128b_1         6.7 MB  conda-forge
#     libiconv-1.18              |       h3b78370_2         772 KB  conda-forge
#     libjpeg-turbo-3.1.2        |       hb03c661_0         619 KB  conda-forge
#     liblapack-3.11.0           |5_h47877c9_openblas          18 KB  conda-forge
#     liblzma-5.8.2              |       hb03c661_0         111 KB  conda-forge
#     libmamba-2.5.0             |       hd28c85e_0         2.4 MB  conda-forge
#     libmamba-spdlog-2.5.0      |       h12fcf84_0          20 KB  conda-forge
#     libmambapy-2.5.0           |  py312h04b9399_0         817 KB  conda-forge
#     libnghttp2-1.67.0          |       had1ee68_0         651 KB  conda-forge
#     libopenblas-0.3.30         |pthreads_h94d23a6_4         5.7 MB  conda-forge
#     libopentelemetry-cpp-1.21.0|       h9692893_2         876 KB  conda-forge
#     libopentelemetry-cpp-headers-1.21.0|       ha770c72_2         354 KB  conda-forge
#     libosqp-1.0.0              |np2py312h1a77e3e_2          84 KB  conda-forge
#     libparquet-23.0.1          |   h7376487_0_cpu         1.3 MB  conda-forge
#     libpng-1.6.55              |       h421ea60_0         310 KB  conda-forge
#     libprotobuf-6.33.5         |       h2b00c02_0         3.5 MB  conda-forge
#     libqdldl-0.1.8             |       h3f2d84a_1          21 KB  conda-forge
#     libre2-11-2025.11.05       |       h0dc7533_1         208 KB  conda-forge
#     libsolv-0.7.35             |       h9463b59_0         506 KB  conda-forge
#     libsqlite-3.51.2           |       hf4e2dac_0         921 KB  conda-forge
#     libstdcxx-15.2.0           |      h934c35e_18         5.6 MB  conda-forge
#     libstdcxx-ng-15.2.0        |      hdf11a46_18          27 KB  conda-forge
#     libthrift-0.22.0           |       h454ac66_1         414 KB  conda-forge
#     libtiff-4.7.1              |       h9d88235_1         425 KB  conda-forge
#     libutf8proc-2.11.3         |       hfe17d71_0          84 KB  conda-forge
#     libuuid-2.41.3             |       h5347b49_0          39 KB  conda-forge
#     libuv-1.51.0               |       hb03c661_1         874 KB  conda-forge
#     libwebp-base-1.6.0         |       hd42ef1d_0         419 KB  conda-forge
#     libxcb-1.17.0              |       h8a09558_0         387 KB  conda-forge
#     libxml2-2.15.1             |       he237659_1          44 KB  conda-forge
#     libxml2-16-2.15.1          |       hca6bf5a_1         543 KB  conda-forge
#     llvmlite-0.46.0            |  py312h7424e68_0        32.5 MB  conda-forge
#     locket-1.0.0               |     pyhd8ed1ab_0           8 KB  conda-forge
#     lz4-4.4.5                  |  py312h3d67a73_1          43 KB  conda-forge
#     mamba-2.5.0                |       h9835478_0         554 KB  conda-forge
#     markupsafe-3.0.3           |  py312h8a5da7c_0          25 KB  conda-forge
#     menuinst-2.4.2             |  py312h7900ff3_0         177 KB  conda-forge
#     msgpack-python-1.1.2       |  py312hd9148b4_1         100 KB  conda-forge
#     narwhals-2.16.0            |     pyhcf101f3_0         273 KB  conda-forge
#     nlohmann_json-3.12.0       |       h54a6638_1         133 KB  conda-forge
#     nlohmann_json-abi-3.12.0   |       h0f90c79_1           4 KB  conda-forge
#     numba-0.63.1               |  py312hd1dde6f_0         5.5 MB  conda-forge
#     numcodecs-0.15.1           |  py312hf79963d_1         795 KB  conda-forge
#     numpy-1.26.4               |  py312heda63a1_0         7.1 MB  conda-forge
#     openjpeg-2.5.4             |       h55fea9a_0         347 KB  conda-forge
#     openssl-3.6.1              |       h35e630c_1         3.0 MB  conda-forge
#     orc-2.2.2                  |       hbb90d81_1         1.3 MB  conda-forge
#     osqp-1.1.1                 |np2py312h0f77346_0         231 KB  conda-forge
#     pandas-3.0.1               |  py312h8ecdadd_0        14.2 MB  conda-forge
#     partd-1.4.2                |     pyhd8ed1ab_0          20 KB  conda-forge
#     pillow-12.1.1              |  py312h50c33e8_0        1006 KB  conda-forge
#     prometheus-cpp-1.3.0       |       ha5d0236_0         195 KB  conda-forge
#     psutil-7.2.2               |  py312h5253ce2_0         220 KB  conda-forge
#     pthread-stubs-0.4          |    hb9d3cd8_1002           8 KB  conda-forge
#     pyarrow-23.0.1             |  py312h7900ff3_0          28 KB  conda-forge
#     pyarrow-core-23.0.1        |py312h2054cf2_0_cpu         4.6 MB  conda-forge
#     pycosat-0.6.6              |  py312h4c3975b_3          86 KB  conda-forge
#     python-3.12.12             |hd63d673_2_cpython        30.0 MB  conda-forge
#     python-dateutil-2.9.0.post0|     pyhe01879c_2         228 KB  conda-forge
#     python_abi-3.12            |          8_cp312           7 KB  conda-forge
#     pywavelets-1.9.0           |  py312h4f23490_2         3.5 MB  conda-forge
#     pyyaml-6.0.3               |  py312h8a5da7c_1         194 KB  conda-forge
#     qdldl-python-0.1.7.post5   |np2py312h0f77346_3         145 KB  conda-forge
#     re2-2025.11.05             |       h5301d42_1          27 KB  conda-forge
#     readline-8.3               |       h853b02a_0         337 KB  conda-forge
#     rhash-1.4.6                |       hb9d3cd8_1         189 KB  conda-forge
#     ruamel.yaml-0.18.17        |  py312h5253ce2_2         281 KB  conda-forge
#     ruamel.yaml.clib-0.2.15    |  py312h5253ce2_1         145 KB  conda-forge
#     s2n-1.6.2                  |       he8a4886_1         385 KB  conda-forge
#     scikit-learn-1.8.0         |np2py312h3226591_1         9.3 MB  conda-forge
#     scipy-1.17.0               |  py312h54fa4ab_1        16.1 MB  conda-forge
#     scs-3.2.11                 |default_py312h250c4f3_0          95 KB  conda-forge
#     simdjson-4.2.4             |       hb700be7_0         288 KB  conda-forge
#     six-1.17.0                 |     pyhe01879c_1          18 KB  conda-forge
#     snappy-1.2.2               |       h03e3b7b_1          45 KB  conda-forge
#     sortedcontainers-2.4.0     |     pyhd8ed1ab_1          28 KB  conda-forge
#     spdlog-1.17.0              |       hab81395_1         192 KB  conda-forge
#     tblib-3.2.2                |     pyhcf101f3_0          19 KB  conda-forge
#     threadpoolctl-3.6.0        |     pyhecae5ae_0          23 KB  conda-forge
#     toolz-1.1.0                |     pyhd8ed1ab_1          53 KB  conda-forge
#     tornado-6.5.4              |  py312h961da02_0         831 KB  conda-forge
#     tqdm-4.67.3                |     pyh8f84b5b_0          92 KB  conda-forge
#     typing_extensions-4.15.0   |     pyhcf101f3_0          50 KB  conda-forge
#     wrapt-2.1.1                |  py312h4c3975b_0          85 KB  conda-forge
#     xorg-libxau-1.0.12         |       hb03c661_1          15 KB  conda-forge
#     xorg-libxdmcp-1.1.5        |       hb03c661_1          20 KB  conda-forge
#     xyzservices-2025.11.0      |     pyhd8ed1ab_0          50 KB  conda-forge
#     yaml-0.2.5                 |       h280c20c_3          83 KB  conda-forge
#     zarr-2.18.7                |     pyhd8ed1ab_0         157 KB  conda-forge
#     zict-3.0.0                 |     pyhd8ed1ab_1          35 KB  conda-forge
#     zipp-3.23.0                |     pyhcf101f3_1          24 KB  conda-forge
#     zlib-1.3.1                 |       hb9d3cd8_2          90 KB  conda-forge
#     zlib-ng-2.3.3              |       hceb46e0_1         120 KB  conda-forge
#     zstandard-0.25.0           |  py312h5253ce2_1         456 KB  conda-forge
#     zstd-1.5.7                 |       hb78ec9c_6         587 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       250.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   asciitree          conda-forge/noarch::asciitree-0.3.3-py_2
#   astra-toolbox      conda-forge/linux-64::astra-toolbox-2.3.1-py312hda1af2d_0
#   aws-c-auth         conda-forge/linux-64::aws-c-auth-0.9.3-hef928c7_0
#   aws-c-cal          conda-forge/linux-64::aws-c-cal-0.9.13-h2c9d079_1
#   aws-c-common       conda-forge/linux-64::aws-c-common-0.12.6-hb03c661_0
#   aws-c-compression  conda-forge/linux-64::aws-c-compression-0.3.1-h8b1a151_9
#   aws-c-event-stream conda-forge/linux-64::aws-c-event-stream-0.5.7-h28f887f_1
#   aws-c-http         conda-forge/linux-64::aws-c-http-0.10.7-ha8fc4e3_5
#   aws-c-io           conda-forge/linux-64::aws-c-io-0.23.3-hdaf4b65_5
#   aws-c-mqtt         conda-forge/linux-64::aws-c-mqtt-0.13.3-hc63082f_11
#   aws-c-s3           conda-forge/linux-64::aws-c-s3-0.11.3-h06ab39a_1
#   aws-c-sdkutils     conda-forge/linux-64::aws-c-sdkutils-0.2.4-h8b1a151_4
#   aws-checksums      conda-forge/linux-64::aws-checksums-0.2.7-h8b1a151_5
#   aws-crt-cpp        conda-forge/linux-64::aws-crt-cpp-0.35.4-h8824e59_0
#   aws-sdk-cpp        conda-forge/linux-64::aws-sdk-cpp-1.11.606-h20b40b1_10
#   azure-core-cpp     conda-forge/linux-64::azure-core-cpp-1.16.2-h206d751_0
#   azure-identity-cpp conda-forge/linux-64::azure-identity-cpp-1.13.3-hed0cdb0_1
#   azure-storage-blo~ conda-forge/linux-64::azure-storage-blobs-cpp-12.16.0-hdd73cc9_1
#   azure-storage-com~ conda-forge/linux-64::azure-storage-common-cpp-12.12.0-ha7a2c86_1
#   azure-storage-fil~ conda-forge/linux-64::azure-storage-files-datalake-cpp-12.14.0-h52c5a47_1
#   bokeh              conda-forge/noarch::bokeh-3.8.2-pyhd8ed1ab_0
#   clarabel           conda-forge/linux-64::clarabel-0.11.1-py312h0ccc70a_2
#   click              conda-forge/noarch::click-8.3.1-pyh8f84b5b_1
#   cloudpickle        conda-forge/noarch::cloudpickle-3.1.2-pyhcf101f3_1
#   cmake              conda-forge/linux-64::cmake-4.2.3-hc85cc9f_1
#   contourpy          conda-forge/linux-64::contourpy-1.3.3-py312h0a2e395_4
#   cpp-expected       conda-forge/linux-64::cpp-expected-1.3.1-h171cf75_0
#   cvxpy              conda-forge/linux-64::cvxpy-1.7.5-py312h217f5b8_1
#   cvxpy-base         conda-forge/linux-64::cvxpy-base-1.7.5-np2py312h0f77346_1
#   cython             conda-forge/linux-64::cython-3.2.4-py312h68e6be4_0
#   cytoolz            conda-forge/linux-64::cytoolz-1.1.0-py312h4c3975b_1
#   dask               conda-forge/noarch::dask-2026.1.2-pyhcf101f3_1
#   dask-core          conda-forge/noarch::dask-core-2026.1.2-pyhcf101f3_0
#   deprecated         conda-forge/noarch::deprecated-1.3.1-pyhd8ed1ab_1
#   distributed        conda-forge/noarch::distributed-2026.1.2-pyhcf101f3_1
#   fasteners          conda-forge/noarch::fasteners-0.19-pyhd8ed1ab_1
#   fsspec             conda-forge/noarch::fsspec-2026.2.0-pyhd8ed1ab_0
#   gflags             conda-forge/linux-64::gflags-2.2.2-h5888daf_1005
#   glog               conda-forge/linux-64::glog-0.7.1-hbabe93e_0
#   icu                conda-forge/linux-64::icu-78.2-h33c6efd_0
#   importlib-metadata conda-forge/noarch::importlib-metadata-8.7.0-pyhe01879c_1
#   jinja2             conda-forge/noarch::jinja2-3.1.6-pyhcf101f3_1
#   joblib             conda-forge/noarch::joblib-1.5.3-pyhd8ed1ab_0
#   lcms2              conda-forge/linux-64::lcms2-2.18-h0c24ade_0
#   lerc               conda-forge/linux-64::lerc-4.0.0-h0aef613_1
#   libabseil          conda-forge/linux-64::libabseil-20260107.1-cxx17_h7b12aa8_0
#   libarrow           conda-forge/linux-64::libarrow-23.0.1-h2603568_0_cpu
#   libarrow-acero     conda-forge/linux-64::libarrow-acero-23.0.1-h635bf11_0_cpu
#   libarrow-compute   conda-forge/linux-64::libarrow-compute-23.0.1-h53684a4_0_cpu
#   libarrow-dataset   conda-forge/linux-64::libarrow-dataset-23.0.1-h635bf11_0_cpu
#   libarrow-substrait conda-forge/linux-64::libarrow-substrait-23.0.1-hb4dd7c2_0_cpu
#   libastra           conda-forge/linux-64::libastra-2.3.1-hd22cb3e_2
#   libblas            conda-forge/linux-64::libblas-3.11.0-5_h4a7cf45_openblas
#   libbrotlicommon    conda-forge/linux-64::libbrotlicommon-1.2.0-hb03c661_1
#   libbrotlidec       conda-forge/linux-64::libbrotlidec-1.2.0-hb03c661_1
#   libbrotlienc       conda-forge/linux-64::libbrotlienc-1.2.0-hb03c661_1
#   libcblas           conda-forge/linux-64::libcblas-3.11.0-5_h0358290_openblas
#   libcrc32c          conda-forge/linux-64::libcrc32c-1.1.2-h9c3ff4c_0
#   libdeflate         conda-forge/linux-64::libdeflate-1.25-h17f619e_0
#   libevent           conda-forge/linux-64::libevent-2.1.12-hf998b51_1
#   libfreetype        conda-forge/linux-64::libfreetype-2.14.1-ha770c72_0
#   libfreetype6       conda-forge/linux-64::libfreetype6-2.14.1-h73754d4_0
#   libgfortran        conda-forge/linux-64::libgfortran-15.2.0-h69a702a_18
#   libgfortran5       conda-forge/linux-64::libgfortran5-15.2.0-h68bc16d_18
#   libgoogle-cloud    conda-forge/linux-64::libgoogle-cloud-2.39.0-h9d11ab5_1
#   libgoogle-cloud-s~ conda-forge/linux-64::libgoogle-cloud-storage-2.39.0-hdbdcf42_1
#   libgrpc            conda-forge/linux-64::libgrpc-1.78.0-h1d1128b_1
#   libjpeg-turbo      conda-forge/linux-64::libjpeg-turbo-3.1.2-hb03c661_0
#   liblapack          conda-forge/linux-64::liblapack-3.11.0-5_h47877c9_openblas
#   libmamba-spdlog    conda-forge/linux-64::libmamba-spdlog-2.5.0-h12fcf84_0
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.30-pthreads_h94d23a6_4
#   libopentelemetry-~ conda-forge/linux-64::libopentelemetry-cpp-1.21.0-h9692893_2
#   libopentelemetry-~ conda-forge/linux-64::libopentelemetry-cpp-headers-1.21.0-ha770c72_2
#   libosqp            conda-forge/linux-64::libosqp-1.0.0-np2py312h1a77e3e_2
#   libparquet         conda-forge/linux-64::libparquet-23.0.1-h7376487_0_cpu
#   libpng             conda-forge/linux-64::libpng-1.6.55-h421ea60_0
#   libprotobuf        conda-forge/linux-64::libprotobuf-6.33.5-h2b00c02_0
#   libqdldl           conda-forge/linux-64::libqdldl-0.1.8-h3f2d84a_1
#   libre2-11          conda-forge/linux-64::libre2-11-2025.11.05-h0dc7533_1
#   libthrift          conda-forge/linux-64::libthrift-0.22.0-h454ac66_1
#   libtiff            conda-forge/linux-64::libtiff-4.7.1-h9d88235_1
#   libutf8proc        conda-forge/linux-64::libutf8proc-2.11.3-hfe17d71_0
#   libuv              conda-forge/linux-64::libuv-1.51.0-hb03c661_1
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.6.0-hd42ef1d_0
#   libxcb             conda-forge/linux-64::libxcb-1.17.0-h8a09558_0
#   libxml2-16         conda-forge/linux-64::libxml2-16-2.15.1-hca6bf5a_1
#   llvmlite           conda-forge/linux-64::llvmlite-0.46.0-py312h7424e68_0
#   locket             conda-forge/noarch::locket-1.0.0-pyhd8ed1ab_0
#   lz4                conda-forge/linux-64::lz4-4.4.5-py312h3d67a73_1
#   markupsafe         conda-forge/linux-64::markupsafe-3.0.3-py312h8a5da7c_0
#   msgpack-python     conda-forge/linux-64::msgpack-python-1.1.2-py312hd9148b4_1
#   narwhals           conda-forge/noarch::narwhals-2.16.0-pyhcf101f3_0
#   nlohmann_json      conda-forge/linux-64::nlohmann_json-3.12.0-h54a6638_1
#   nlohmann_json-abi  conda-forge/noarch::nlohmann_json-abi-3.12.0-h0f90c79_1
#   numba              conda-forge/linux-64::numba-0.63.1-py312hd1dde6f_0
#   numcodecs          conda-forge/linux-64::numcodecs-0.15.1-py312hf79963d_1
#   numpy              conda-forge/linux-64::numpy-1.26.4-py312heda63a1_0
#   openjpeg           conda-forge/linux-64::openjpeg-2.5.4-h55fea9a_0
#   orc                conda-forge/linux-64::orc-2.2.2-hbb90d81_1
#   osqp               conda-forge/linux-64::osqp-1.1.1-np2py312h0f77346_0
#   pandas             conda-forge/linux-64::pandas-3.0.1-py312h8ecdadd_0
#   partd              conda-forge/noarch::partd-1.4.2-pyhd8ed1ab_0
#   pillow             conda-forge/linux-64::pillow-12.1.1-py312h50c33e8_0
#   prometheus-cpp     conda-forge/linux-64::prometheus-cpp-1.3.0-ha5d0236_0
#   psutil             conda-forge/linux-64::psutil-7.2.2-py312h5253ce2_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-hb9d3cd8_1002
#   pyarrow            conda-forge/linux-64::pyarrow-23.0.1-py312h7900ff3_0
#   pyarrow-core       conda-forge/linux-64::pyarrow-core-23.0.1-py312h2054cf2_0_cpu
#   python-dateutil    conda-forge/noarch::python-dateutil-2.9.0.post0-pyhe01879c_2
#   pywavelets         conda-forge/linux-64::pywavelets-1.9.0-py312h4f23490_2
#   pyyaml             conda-forge/linux-64::pyyaml-6.0.3-py312h8a5da7c_1
#   qdldl-python       conda-forge/linux-64::qdldl-python-0.1.7.post5-np2py312h0f77346_3
#   re2                conda-forge/linux-64::re2-2025.11.05-h5301d42_1
#   rhash              conda-forge/linux-64::rhash-1.4.6-hb9d3cd8_1
#   s2n                conda-forge/linux-64::s2n-1.6.2-he8a4886_1
#   scikit-learn       conda-forge/linux-64::scikit-learn-1.8.0-np2py312h3226591_1
#   scipy              conda-forge/linux-64::scipy-1.17.0-py312h54fa4ab_1
#   scs                conda-forge/linux-64::scs-3.2.11-default_py312h250c4f3_0
#   simdjson           conda-forge/linux-64::simdjson-4.2.4-hb700be7_0
#   six                conda-forge/noarch::six-1.17.0-pyhe01879c_1
#   snappy             conda-forge/linux-64::snappy-1.2.2-h03e3b7b_1
#   sortedcontainers   conda-forge/noarch::sortedcontainers-2.4.0-pyhd8ed1ab_1
#   spdlog             conda-forge/linux-64::spdlog-1.17.0-hab81395_1
#   tblib              conda-forge/noarch::tblib-3.2.2-pyhcf101f3_0
#   threadpoolctl      conda-forge/noarch::threadpoolctl-3.6.0-pyhecae5ae_0
#   toolz              conda-forge/noarch::toolz-1.1.0-pyhd8ed1ab_1
#   tornado            conda-forge/linux-64::tornado-6.5.4-py312h961da02_0
#   typing_extensions  conda-forge/noarch::typing_extensions-4.15.0-pyhcf101f3_0
#   wrapt              conda-forge/linux-64::wrapt-2.1.1-py312h4c3975b_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.12-hb03c661_1
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.5-hb03c661_1
#   xyzservices        conda-forge/noarch::xyzservices-2025.11.0-pyhd8ed1ab_0
#   yaml               conda-forge/linux-64::yaml-0.2.5-h280c20c_3
#   zarr               conda-forge/noarch::zarr-2.18.7-pyhd8ed1ab_0
#   zict               conda-forge/noarch::zict-3.0.0-pyhd8ed1ab_1
#   zipp               conda-forge/noarch::zipp-3.23.0-pyhcf101f3_1
#   zlib               conda-forge/linux-64::zlib-1.3.1-hb9d3cd8_2
#   zlib-ng            conda-forge/linux-64::zlib-ng-2.3.3-hceb46e0_1
#
# The following packages will be UPDATED:
#
#   brotli-python                       1.1.0-py311hfdbb021_2 --> 1.2.0-py312hdb49522_1
#   c-ares                                  1.34.4-hb9d3cd8_0 --> 1.34.6-hb03c661_0
#   ca-certificates    conda-forge/linux-64::ca-certificates~ --> conda-forge/noarch::ca-certificates-2026.1.4-hbd8a1cb_0
#   certifi                           2024.12.14-pyhd8ed1ab_0 --> 2026.1.4-pyhd8ed1ab_0
#   cffi                               1.17.1-py311hf29c0ef_0 --> 2.0.0-py312h460c074_1
#   conda                             24.11.2-py311h38be061_1 --> 26.1.0-py312h7900ff3_0
#   conda-libmamba-so~                    24.9.0-pyhd8ed1ab_0 --> 25.11.0-pyhd8ed1ab_1
#   fmt                                     11.0.2-h434a139_0 --> 12.1.0-hff5e90c_0
#   frozendict                          2.4.6-py311h9ecbd09_0 --> 2.4.7-py312h4c3975b_0
#   jsonpointer        conda-forge/linux-64::jsonpointer-3.0~ --> conda-forge/noarch::jsonpointer-3.0.0-pyhcf101f3_3
#   libarchive                               3.7.7-h4585015_3 --> 3.8.5-gpl_hc2c16d8_100
#   libcurl                                 8.11.1-h332b0f4_0 --> 8.18.0-h4e3cde8_0
#   libexpat                                 2.6.4-h5888daf_0 --> 2.7.4-hecca717_0
#   libffi                                   3.4.2-h7f98852_5 --> 3.5.2-h3435931_0
#   libgcc                                  14.2.0-h77fa898_1 --> 15.2.0-he0feb66_18
#   libgcc-ng                               14.2.0-h69a702a_1 --> 15.2.0-h69a702a_18
#   libgomp                                 14.2.0-h77fa898_1 --> 15.2.0-he0feb66_18
#   libiconv                                  1.17-hd590300_2 --> 1.18-h3b78370_2
#   liblzma                                  5.6.3-hb9d3cd8_1 --> 5.8.2-hb03c661_0
#   libmamba                                1.5.12-h49b8a8d_0 --> 2.5.0-hd28c85e_0
#   libmambapy                         1.5.12-py311hb3373dd_0 --> 2.5.0-py312h04b9399_0
#   libnghttp2                              1.64.0-h161d5f1_0 --> 1.67.0-had1ee68_0
#   libsolv                                 0.7.30-h3509ff9_0 --> 0.7.35-h9463b59_0
#   libsqlite                               3.47.2-hee588c1_0 --> 3.51.2-hf4e2dac_0
#   libstdcxx                               14.2.0-hc0a3c3a_1 --> 15.2.0-h934c35e_18
#   libstdcxx-ng                            14.2.0-h4852527_1 --> 15.2.0-hdf11a46_18
#   libuuid                                 2.38.1-h0b41bf4_0 --> 2.41.3-h5347b49_0
#   libxml2                                 2.13.5-h0d44e9d_1 --> 2.15.1-he237659_1
#   mamba                              1.5.12-py311h3072747_0 --> 2.5.0-h9835478_0
#   menuinst                            2.2.0-py311h38be061_0 --> 2.4.2-py312h7900ff3_0
#   openssl                                  3.4.0-h7b32b05_1 --> 3.6.1-h35e630c_1
#   pycosat                             0.6.6-py311h9ecbd09_2 --> 0.6.6-py312h4c3975b_3
#   python                         3.11.11-h9e4cc4f_1_cpython --> 3.12.12-hd63d673_2_cpython
#   python_abi         conda-forge/linux-64::python_abi-3.11~ --> conda-forge/noarch::python_abi-3.12-8_cp312
#   readline                                   8.2-h8228510_1 --> 8.3-h853b02a_0
#   ruamel.yaml                       0.18.10-py311h9ecbd09_0 --> 0.18.17-py312h5253ce2_2
#   ruamel.yaml.clib                    0.2.8-py311h9ecbd09_1 --> 0.2.15-py312h5253ce2_1
#   tqdm                                  4.67.1-pyhd8ed1ab_1 --> 4.67.3-pyh8f84b5b_0
#   zstandard                          0.23.0-py311hbc35293_1 --> 0.25.0-py312h5253ce2_1
#   zstd                                     1.5.6-ha6fb4c9_0 --> 1.5.7-hb78ec9c_6
#
#
#
# Downloading and Extracting Packages:
# llvmlite-0.46.0      | 32.5 MB   | :   0% 0/1 [00:00<?, ?it/s]
# python-3.12.12       | 30.0 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
# cmake-4.2.3          | 21.3 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
# scipy-1.17.0         | 16.1 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# pandas-3.0.1         | 14.2 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# icu-78.2             | 12.1 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# scikit-learn-1.8.0   | 9.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# numpy-1.26.4         | 7.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# libgrpc-1.78.0       | 6.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# libarrow-23.0.1      | 6.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.30   | 5.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# libstdcxx-15.2.0     | 5.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# numba-0.63.1         | 5.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# pyarrow-core-23.0.1  | 4.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# bokeh-3.8.2          | 4.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-3.2.4         | 3.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pywavelets-1.9.0     | 3.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libprotobuf-6.33.5   | 3.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.11.606 | 3.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# llvmlite-0.46.0      | 32.5 MB   | :   0% 0.0004802803495833559/1 [00:00<04:32, 272.42s/it]
# python-3.12.12       | 30.0 MB   | :   0% 0.0005208249722604436/1 [00:00<04:12, 252.79s/it]
#
#
# scipy-1.17.0         | 16.1 MB   | :   0% 0.0009692656304287882/1 [00:00<02:19, 139.31s/it]
#
#
#
# pandas-3.0.1         | 14.2 MB   | :   0% 0.001104021849713678/1 [00:00<02:29, 150.01s/it]
#
# llvmlite-0.46.0      | 32.5 MB   | :   7% 0.07012093103916997/1 [00:00<00:02,  2.74s/it]
# python-3.12.12       | 30.0 MB   | :   8% 0.07968622075584787/1 [00:00<00:02,  2.42s/it]
#
#
# scipy-1.17.0         | 16.1 MB   | :  15% 0.15120543834689096/1 [00:00<00:01,  1.29s/it]
#
#
#
# pandas-3.0.1         | 14.2 MB   | :  13% 0.12917055641650033/1 [00:00<00:01,  1.68s/it]
#
# llvmlite-0.46.0      | 32.5 MB   | :  16% 0.15945307606167416/1 [00:00<00:01,  1.69s/it]
# python-3.12.12       | 30.0 MB   | :  17% 0.16666399112334196/1 [00:00<00:01,  1.65s/it]
#
#
# scipy-1.17.0         | 16.1 MB   | :  34% 0.3363351737587895/1 [00:00<00:00,  1.23it/s]
#
#
#
# pandas-3.0.1         | 14.2 MB   | :  35% 0.34887090450952224/1 [00:00<00:00,  1.23it/s]
#
# llvmlite-0.46.0      | 32.5 MB   | :  26% 0.2636739119212624/1 [00:00<00:00,  1.31s/it]
# python-3.12.12       | 30.0 MB   | :  27% 0.26562073585282625/1 [00:00<00:00,  1.33s/it]
#
#
# scipy-1.17.0         | 16.1 MB   | :  51% 0.5088644559751139/1 [00:00<00:00,  1.41it/s]
#
#
#
# pandas-3.0.1         | 14.2 MB   | :  55% 0.5464908156082706/1 [00:00<00:00,  1.50it/s]
#
# llvmlite-0.46.0      | 32.5 MB   | :  34% 0.34292016960251614/1 [00:00<00:00,  1.31s/it]
# python-3.12.12       | 30.0 MB   | :  35% 0.346348606553195/1 [00:00<00:00,  1.30s/it]
#
#
# scipy-1.17.0         | 16.1 MB   | :  67% 0.6658854881045775/1 [00:00<00:00,  1.46it/s]
#
#
#
# pandas-3.0.1         | 14.2 MB   | :  72% 0.7231343115624591/1 [00:00<00:00,  1.59it/s]
#
# llvmlite-0.46.0      | 32.5 MB   | :  45% 0.44521988406377094/1 [00:00<00:00,  1.18s/it]
# python-3.12.12       | 30.0 MB   | :  44% 0.4416595764768562/1 [00:00<00:00,  1.21s/it]
#
#
# scipy-1.17.0         | 16.1 MB   | :  87% 0.8723390673859094/1 [00:00<00:00,  1.66it/s]
#
#
#
# pandas-3.0.1         | 14.2 MB   | :  94% 0.9406266159560537/1 [00:00<00:00,  1.78it/s]
#
# llvmlite-0.46.0      | 32.5 MB   | :  54% 0.5364731504846085/1 [00:00<00:00,  1.15s/it]
# llvmlite-0.46.0      | 32.5 MB   | :  65% 0.6512601540350306/1 [00:00<00:00,  1.05s/it]
# python-3.12.12       | 30.0 MB   | :  65% 0.6531145152145963/1 [00:00<00:00,  1.05s/it]
# llvmlite-0.46.0      | 32.5 MB   | :  75% 0.7477965043012852/1 [00:00<00:00,  1.12s/it]
#
#
# scipy-1.17.0         | 16.1 MB   | : 100% 1.0/1 [00:01<00:00,  1.66it/s]
#
#
#
# pandas-3.0.1         | 14.2 MB   | : 100% 1.0/1 [00:01<00:00,  1.78it/s]
# llvmlite-0.46.0      | 32.5 MB   | :  84% 0.8385694903725395/1 [00:01<00:00,  1.24s/it]
#
#
#
#
# icu-78.2             | 12.1 MB   | :   0% 0.001287195725793685/1 [00:01<14:06, 847.17s/it]
#
#
#
#
#
# scikit-learn-1.8.0   | 9.3 MB    | :   0% 0.0016845234306989384/1 [00:01<10:51, 652.20s/it]
# python-3.12.12       | 30.0 MB   | :  96% 0.9630053737095603/1 [00:01<00:00,  1.05s/it]
#
#
#
#
# icu-78.2             | 12.1 MB   | :  11% 0.1106988324182569/1 [00:01<00:06,  7.86s/it]
#
#
#
#
#
# llvmlite-0.46.0      | 32.5 MB   | :  92% 0.92165799085046/1 [00:01<00:00,  1.33s/it]
#
#
#
#
# icu-78.2             | 12.1 MB   | :  25% 0.2471415793523875/1 [00:01<00:02,  3.31s/it]
#
#
#
#
#
# llvmlite-0.46.0      | 32.5 MB   | : 100% 0.9989831271333803/1 [00:01<00:00,  1.38s/it]
#
# cmake-4.2.3          | 21.3 MB   | : 100% 1.0/1 [00:01<00:00,  1.93s/it]
#
# cmake-4.2.3          | 21.3 MB   | : 100% 1.0/1 [00:01<00:00,  1.93s/it]
#
#
#
#
# icu-78.2             | 12.1 MB   | :  42% 0.4183386108829476/1 [00:01<00:01,  1.87s/it]
#
#
#
#
#
# scikit-learn-1.8.0   | 9.3 MB    | :  54% 0.5390474978236603/1 [00:01<00:00,  1.49s/it]
#
#
#
#
#
#
# numpy-1.26.4         | 7.1 MB    | :   0% 0.002189149227451055/1 [00:01<10:59, 660.45s/it]
#
#
#
#
# icu-78.2             | 12.1 MB   | :  57% 0.5689405108008088/1 [00:01<00:00,  1.39s/it]
#
#
#
#
#
# scikit-learn-1.8.0   | 9.3 MB    | :  74% 0.7361367392154361/1 [00:01<00:00,  1.09s/it]
#
#
#
#
#
#
# numpy-1.26.4         | 7.1 MB    | :  25% 0.24518471347451815/1 [00:01<00:03,  4.55s/it]
#
#
#
#
#
# scikit-learn-1.8.0   | 9.3 MB    | :  97% 0.9702854960825885/1 [00:01<00:00,  1.23it/s]
#
#
#
#
# icu-78.2             | 12.1 MB   | :  70% 0.7015216705575583/1 [00:01<00:00,  1.18s/it]
#
#
#
#
#
#
# numpy-1.26.4         | 7.1 MB    | :  55% 0.5450981576353127/1 [00:01<00:00,  1.87s/it]
#
#
#
#
# icu-78.2             | 12.1 MB   | :  94% 0.9370784883778026/1 [00:01<00:00,  1.19it/s]
#
#
#
#
#
#
# numpy-1.26.4         | 7.1 MB    | :  92% 0.9238209739843452/1 [00:01<00:00,  1.01s/it]
#
#
#
#
#
# scikit-learn-1.8.0   | 9.3 MB    | : 100% 1.0/1 [00:01<00:00,  1.23it/s]
#
#
#
#
#
#
#
# libgrpc-1.78.0       | 6.7 MB    | :   0% 0.0023432196014667433/1 [00:01<13:24, 806.38s/it]
#
#
#
#
#
#
# numpy-1.26.4         | 7.1 MB    | : 100% 1.0/1 [00:01<00:00,  1.01s/it]
#
#
#
#
#
#
#
# libgrpc-1.78.0       | 6.7 MB    | :  27% 0.274156693371609/1 [00:01<00:03,  5.20s/it]
#
#
#
#
#
#
#
#
# libarrow-23.0.1      | 6.2 MB    | :   0% 0.0025226230044310648/1 [00:02<13:22, 804.79s/it]
#
#
#
#
#
#
#
# libgrpc-1.78.0       | 6.7 MB    | :  69% 0.6889065628312225/1 [00:02<00:00,  1.81s/it]
#
#
#
#
# icu-78.2             | 12.1 MB   | : 100% 1.0/1 [00:02<00:00,  1.19it/s]
# python-3.12.12       | 30.0 MB   | : 100% 1.0/1 [00:02<00:00,  1.05s/it]
#
#
#
#
#
#
#
#
# libarrow-23.0.1      | 6.2 MB    | :  40% 0.3960518116956772/1 [00:02<00:02,  3.85s/it]
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.30   | 5.7 MB    | :   0% 0.0027638610991105005/1 [00:02<13:03, 786.09s/it]
#
#
#
#
#
#
#
#
#
#
# libstdcxx-15.2.0     | 5.6 MB    | :   0% 0.002799568718783801/1 [00:02<12:53, 776.06s/it]
#
#
#
#
#
#
#
#
# llvmlite-0.46.0      | 32.5 MB   | : 100% 1.0/1 [00:02<00:00,  1.38s/it]
#
#
#
#
#
#
#
#
#
#
# libstdcxx-15.2.0     | 5.6 MB    | :  41% 0.4087370329424349/1 [00:02<00:02,  3.97s/it]
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.30   | 5.7 MB    | :  45% 0.447745498055901/1 [00:02<00:02,  3.63s/it]
#
#
#
#
#
#
#
#
#
#
#
# numba-0.63.1         | 5.5 MB    | :   0% 0.002862375537590779/1 [00:02<13:17, 799.34s/it]
#
#
#
#
#
#
#
# libgrpc-1.78.0       | 6.7 MB    | : 100% 1.0/1 [00:02<00:00,  1.42s/it]
#
#
#
#
#
#
#
# libgrpc-1.78.0       | 6.7 MB    | : 100% 1.0/1 [00:02<00:00,  1.42s/it]
#
#
#
#
#
#
#
#
#
#
# libstdcxx-15.2.0     | 5.6 MB    | :  82% 0.8202736346036535/1 [00:02<00:00,  1.77s/it]
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.30   | 5.7 MB    | :  81% 0.8098113020393766/1 [00:02<00:00,  1.83s/it]
#
#
#
#
#
#
#
#
#
#
#
# numba-0.63.1         | 5.5 MB    | :  59% 0.5867869852061097/1 [00:02<00:01,  2.91s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# pyarrow-core-23.0.1  | 4.6 MB    | :   0% 0.0034299457036915462/1 [00:02<11:43, 706.01s/it]
#
#
#
#
#
#
#
#
#
#
#
# numba-0.63.1         | 5.5 MB    | :  93% 0.9274096741794124/1 [00:02<00:00,  1.72s/it]
#
#
#
#
#
#
#
#
# libarrow-23.0.1      | 6.2 MB    | : 100% 1.0/1 [00:02<00:00,  1.84s/it]
#
#
#
#
#
#
#
#
#
#
# libstdcxx-15.2.0     | 5.6 MB    | : 100% 1.0/1 [00:02<00:00,  1.77s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# pyarrow-core-23.0.1  | 4.6 MB    | :  43% 0.4253132672577517/1 [00:02<00:02,  4.23s/it]
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.30   | 5.7 MB    | : 100% 1.0/1 [00:02<00:00,  1.83s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# bokeh-3.8.2          | 4.5 MB    | :   0% 0.003476318429410197/1 [00:02<12:11, 734.51s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-3.2.4         | 3.6 MB    | :   0% 0.004382893233855068/1 [00:02<09:45, 587.64s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pywavelets-1.9.0     | 3.5 MB    | :   0% 0.004455962692191268/1 [00:02<09:42, 585.43s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# pyarrow-core-23.0.1  | 4.6 MB    | :  96% 0.9603847970336329/1 [00:02<00:00,  1.63s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# bokeh-3.8.2          | 4.5 MB    | :  73% 0.7300268701761414/1 [00:02<00:00,  2.59s/it]
#
#
#
#
#
#
#
#
#
#
#
# numba-0.63.1         | 5.5 MB    | : 100% 1.0/1 [00:02<00:00,  1.72s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-3.2.4         | 3.6 MB    | :  57% 0.5697761204011589/1 [00:02<00:01,  3.35s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pywavelets-1.9.0     | 3.5 MB    | :  79% 0.7887053965178544/1 [00:02<00:00,  2.45s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libprotobuf-6.33.5   | 3.5 MB    | :   0% 0.00450270948564569/1 [00:02<10:00, 603.68s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# pyarrow-core-23.0.1  | 4.6 MB    | : 100% 1.0/1 [00:02<00:00,  1.63s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# bokeh-3.8.2          | 4.5 MB    | : 100% 1.0/1 [00:02<00:00,  2.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.11.606 | 3.3 MB    | :   0% 0.0047179781344289734/1 [00:02<09:53, 596.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-3.2.4         | 3.6 MB    | : 100% 1.0/1 [00:02<00:00,  1.78s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libprotobuf-6.33.5   | 3.5 MB    | :  78% 0.78347145050235/1 [00:02<00:00,  2.56s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-3.2.4         | 3.6 MB    | : 100% 1.0/1 [00:02<00:00,  1.78s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pywavelets-1.9.0     | 3.5 MB    | : 100% 1.0/1 [00:02<00:00,  2.45s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.11.606 | 3.3 MB    | :  82% 0.8162102172562123/1 [00:02<00:00,  2.54s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libprotobuf-6.33.5   | 3.5 MB    | : 100% 1.0/1 [00:02<00:00,  2.56s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.11.606 | 3.3 MB    | : 100% 1.0/1 [00:03<00:00,  2.54s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# scipy-1.17.0         | 16.1 MB   | : 100% 1.0/1 [00:05<00:00,  1.66it/s]
#
#
#
# pandas-3.0.1         | 14.2 MB   | : 100% 1.0/1 [00:06<00:00,  1.78it/s]
#
#
#
#
#
# scikit-learn-1.8.0   | 9.3 MB    | : 100% 1.0/1 [00:08<00:00,  1.23it/s]
#
# cmake-4.2.3          | 21.3 MB   | : 100% 1.0/1 [00:10<00:00,  1.93s/it]
#
#
#
#
#
#
# numpy-1.26.4         | 7.1 MB    | : 100% 1.0/1 [00:10<00:00,  1.01s/it]
#
#
#
#
# llvmlite-0.46.0      | 32.5 MB   | : 100% 1.0/1 [00:12<00:00,  1.38s/it]
# python-3.12.12       | 30.0 MB   | : 100% 1.0/1 [00:12<00:00,  1.05s/it]
#
#
#
#
#
#
#
#
# libarrow-23.0.1      | 6.2 MB    | : 100% 1.0/1 [00:13<00:00,  1.84s/it]
#
#
#
#
#
#
#
# libgrpc-1.78.0       | 6.7 MB    | : 100% 1.0/1 [00:13<00:00,  1.42s/it]
#
#
#
#
#
#
#
#
#
#
# libstdcxx-15.2.0     | 5.6 MB    | : 100% 1.0/1 [00:14<00:00,  1.77s/it]
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.30   | 5.7 MB    | : 100% 1.0/1 [00:14<00:00,  1.83s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# pyarrow-core-23.0.1  | 4.6 MB    | : 100% 1.0/1 [00:15<00:00,  1.63s/it]
#
#
#
#
#
#
#
#
#
#
#
# numba-0.63.1         | 5.5 MB    | : 100% 1.0/1 [00:16<00:00,  1.72s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-3.2.4         | 3.6 MB    | : 100% 1.0/1 [00:17<00:00,  1.78s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pywavelets-1.9.0     | 3.5 MB    | : 100% 1.0/1 [00:17<00:00,  2.45s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# bokeh-3.8.2          | 4.5 MB    | : 100% 1.0/1 [00:17<00:00,  2.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libprotobuf-6.33.5   | 3.5 MB    | : 100% 1.0/1 [00:17<00:00,  2.56s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.11.606 | 3.3 MB    | : 100% 1.0/1 [00:18<00:00,  2.54s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done

# %%
# !pip install -U "setuptools<82"
# Out:
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/site-packages (65.6.3)
# Collecting setuptools<82
#   Downloading setuptools-81.0.0-py3-none-any.whl.metadata (6.6 kB)
# Downloading setuptools-81.0.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 20.9 MB/s eta 0:00:00
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 65.6.3
#     Uninstalling setuptools-65.6.3:
#       Successfully uninstalled setuptools-65.6.3
# Successfully installed setuptools-81.0.0

# %%
# %%bash
#
# git config --global user.email "your_github_email"
# git config --global user.name "your_github_username"
#
# cd /content
# git clone https://github.com/epapoutsellis/StochasticCIL.git
# cd StochasticCIL
# git checkout svrg
#
# git tag -a v1.0 -m "Version 1.0" || true
#
# mkdir -p build
# cd build
# cmake ../ -DCMAKE_POLICY_VERSION_MINIMUM=3.5 -DCONDA_BUILD=OFF -DCMAKE_BUILD_TYPE=Release -DCMAKE_INSTALL_PREFIX=/usr/local
# make -j"$(nproc)"
# make install
# Out:
# Your branch is up to date with 'origin/svrg'.
# -- python version
# -- Python wrappers will be installed in /usr/local/lib/python3.12/site-packages
# -- Found PYTHON_EXECUTABLE=/usr/local/bin/python
# -- Python version 3.12.12
# -- Found PYTHON_INCLUDE_DIRS=/usr/local/include/python3.12
# -- Found PYTHON_LIBRARIES=/usr/local/lib/libpython3.12.so
# -- Configuring done (0.8s)
# -- Generating done (0.0s)
# -- Build files have been written to: /content/StochasticCIL/build
# [100%] Built target cilacc
# Processing /content/StochasticCIL/Wrappers/Python
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: cil
#   Building wheel for cil (setup.py): started
#   Building wheel for cil (setup.py): finished with status 'done'
#   Created wheel for cil: filename=cil-1.0.0-py3-none-any.whl size=270119 sha256=1ce93b9ed25f7a63a4a8fb65f132d0f0bed8b56f4ec019ec6e36efbf70e304b5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0zjnzlmn/wheels/78/21/40/a410e7c46380add0d5aa3bf7442b56e11b98510323a0b4ec8f
# Successfully built cil
# Installing collected packages: cil
# Successfully installed cil-1.0.0
# [100%] Built target pythonsetup
# [100%] Built target PythonWrapper
# [100%] Built target cilacc
# Processing /content/StochasticCIL/Wrappers/Python
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: cil
#   Building wheel for cil (setup.py): started
#   Building wheel for cil (setup.py): finished with status 'done'
#   Created wheel for cil: filename=cil-1.0.0-py3-none-any.whl size=270119 sha256=d1a1976e52695dc3aaf38ace3b92326bc6116c0213a38f4434d02628a22ba265
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xdzv5x76/wheels/78/21/40/a410e7c46380add0d5aa3bf7442b56e11b98510323a0b4ec8f
# Successfully built cil
# Installing collected packages: cil
# Successfully installed cil-1.0.0
# [100%] Built target pythonsetup
# [100%] Built target PythonWrapper
# Install the project...
# -- Install configuration: "Release"
# -- Installing: /usr/local/lib/libcilacc.so
# -- Installing: /usr/local/include/cil
# -- Installing: /usr/local/include/cil/FiniteDifferenceLibrary.h
# -- Installing: /usr/local/include/cil/axpby.h
# -- Installing: /usr/local/include/cil/dll_export.h
# -- Installing: /usr/local/include/cil/utilities.h
# -- Installing: /usr/local/include/cil/FBP_filtering.h
# -- Installing: /usr/local/share/cil
# fatal: destination path 'StochasticCIL' already exists and is not an empty directory.
# Already on 'svrg'
# fatal: tag 'v1.0' already exists
# CMake Deprecation Warning at CMakeLists.txt:4 (cmake_minimum_required):
#   Compatibility with CMake < 3.10 will be removed from a future version of
#   CMake.
#
#   Update the VERSION argument <min> value.  Or, use the <min>...<max> syntax
#   to tell CMake that the project requires at least <min> but has been updated
#   to work with policies introduced by <max> or earlier.
#
#
# /content/StochasticCIL/Wrappers/Python/CMake/parse_git_describe.py:5: SyntaxWarning: invalid escape sequence '\.'
#   pattern = re.compile('v([0-9]*)\.([0-9]*)(\.*)([0-9]*)')
# OpenMP_CXX_FLAGS -fopenmp
# CMAKE_CXX_FLAGS
# CMAKE_EXE_LINKER_FLAGS
# CMAKE_SHARED_LINKER_FLAGS
# CMAKE_STATIC_LINKER_FLAGS
# IPP libraries not found, FBP_filtering not in build
# I'd install into /usr/local/lib
# CMake Warning (dev) at Wrappers/Python/CMakeLists.txt:4 (find_package):
#   Policy CMP0148 is not set: The FindPythonInterp and FindPythonLibs modules
#   are removed.  Run "cmake --help-policy CMP0148" for policy details.  Use
#   the cmake_policy command to set the policy and suppress this warning.
#
# This warning is for project developers.  Use -Wno-dev to suppress it.
#
# CMAKE_CXX_FLAGS
# CMake Warning (dev) at Wrappers/Python/CMakeLists.txt:29 (find_package):
#   Policy CMP0148 is not set: The FindPythonInterp and FindPythonLibs modules
#   are removed.  Run "cmake --help-policy CMP0148" for policy details.  Use
#   the cmake_policy command to set the policy and suppress this warning.
#
# This warning is for project developers.  Use -Wno-dev to suppress it.
#
# Python found /usr/local/bin/python

# %%
# !git clone https://github.com/epapoutsellis/Split-Skip-and-Play.git
# Out:
# Cloning into 'Split-Skip-and-Play'...
# remote: Enumerating objects: 101, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 101 (delta 9), reused 14 (delta 5), pack-reused 80 (from 1)
# Receiving objects: 100% (101/101), 31.18 MiB | 26.43 MiB/s, done.
# Resolving deltas: 100% (40/40), done.

# %%
# !pip install bm3d xdesign scikit-image
# Out:
# Collecting bm3d
#   Downloading bm3d-4.0.3-py3-none-any.whl.metadata (2.3 kB)
# Collecting xdesign
#   Downloading xdesign-0.5.5.tar.gz (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 32.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting scikit-image
#   Downloading scikit_image-0.26.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (15 kB)
# Collecting bm4d>=4.2.5 (from bm3d)
#   Downloading bm4d-4.2.5-py3-none-any.whl.metadata (3.1 kB)
# Collecting cached-property (from xdesign)
#   Downloading cached_property-2.0.1-py3-none-any.whl.metadata (10 kB)
# Collecting matplotlib (from xdesign)
#   Downloading matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/site-packages (from xdesign) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/site-packages (from xdesign) (1.17.0)
# Collecting networkx>=3.0 (from scikit-image)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.12/site-packages (from scikit-image) (12.1.1)
# Collecting imageio!=2.35.0,>=2.33 (from scikit-image)
#   Downloading imageio-2.37.2-py3-none-any.whl.metadata (9.7 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image)
#   Downloading tifffile-2026.2.16-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/site-packages (from scikit-image) (24.2)
# Collecting lazy-loader>=0.4 (from scikit-image)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.12/site-packages (from bm4d>=4.2.5->bm3d) (1.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/site-packages (from matplotlib->xdesign) (1.3.3)
# Collecting cycler>=0.10 (from matplotlib->xdesign)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->xdesign)
#   Downloading fonttools-4.61.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->xdesign)
#   Downloading kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.3 kB)
# Collecting pyparsing>=3 (from matplotlib->xdesign)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/site-packages (from matplotlib->xdesign) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->xdesign) (1.17.0)
# Downloading bm3d-4.0.3-py3-none-any.whl (10 kB)
# Downloading scikit_image-0.26.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (13.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 118.5 MB/s eta 0:00:00
# Downloading bm4d-4.2.5-py3-none-any.whl (862 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 862.0/862.0 kB 31.5 MB/s eta 0:00:00
# Downloading imageio-2.37.2-py3-none-any.whl (317 kB)
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 62.6 MB/s eta 0:00:00
# Downloading tifffile-2026.2.16-py3-none-any.whl (233 kB)
# Downloading cached_property-2.0.1-py3-none-any.whl (7.4 kB)
# Downloading matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 119.9 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 108.8 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 55.6 MB/s eta 0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Building wheels for collected packages: xdesign
#   Building wheel for xdesign (setup.py) ... done
#   Created wheel for xdesign: filename=xdesign-0.5.5-py3-none-any.whl size=74650 sha256=b9fadb5d2a5524b02c51ada4470932f643d2b5000fdfce73b26a1821d6ff8d37
#   Stored in directory: /root/.cache/pip/wheels/e2/5d/fe/0b9f5ea4c32c7adb9a1771b48481ecea70f0e9fa68b4e799d6
# Successfully built xdesign
# Installing collected packages: tifffile, pyparsing, networkx, lazy-loader, kiwisolver, imageio, fonttools, cycler, cached-property, scikit-image, matplotlib, bm4d, xdesign, bm3d
# Successfully installed bm3d-4.0.3 bm4d-4.2.5 cached-property-2.0.1 cycler-0.12.1 fonttools-4.61.1 imageio-2.37.2 kiwisolver-1.4.9 lazy-loader-0.4 matplotlib-3.10.8 networkx-3.6.1 pyparsing-3.3.2 scikit-image-0.26.0 tifffile-2026.2.16 xdesign-0.5.5

# %%
# %cd Split-Skip-and-Play/
# Out:
# /content/Split-Skip-and-Play

# %%
from cil.optimisation.functions import LeastSquares, SVRGFunction, SGFunction
from cil.framework import AcquisitionGeometry
from cil.plugins.astra import ProjectionOperator
from cil.plugins.astra import FBP
from cil.optimisation.utilities import MetricsDiagnostics, RandomSampling
from cil.optimisation.algorithms import FISTA, ISTA

from ProxSkip import ProxSkip
from utils import StoppingCriterionTime, BM3DFunction
from skimage.metrics import peak_signal_noise_ratio as PSNR
from skimage.metrics import structural_similarity as SSIM
from xdesign import Foam, discrete_phantom

import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["image.cmap"]  = "inferno"
# Out:
# /usr/local/lib/python3.12/site-packages/xdesign/__init__.py:57: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import get_distribution, DistributionNotFound

# %% [markdown]
# ### PnP Variance Reduced ProxSkip on a simulated dataset

# %% [markdown]
# In this notebook, we play the following game. We compare algorithms by **time-to-quality**: that is, we measure how quickly each method achieves high reconstruction quality—quantified by **PSNR** and **SSIM**—with respect to the ground truth. Here, the ground truth is available, and we impose a fixed computational budget. The winner is the algorithm that attains the highest PSNR/SSIM within this time limit.

# %% [markdown]
# ### Generate Foam Phantom

# %%
N = 347  # image size
density = 0.025  # attenuation density of the image
np.random.seed(1234)
gt = discrete_phantom(Foam(size_range=[0.075, 0.005], gap=2e-3, porosity=1.0), size=N - 10)
gt = gt / np.max(gt) * density
gt = np.pad(gt, 5)
gt[gt < 0] = 0

# %% [markdown]
# ### Generate Acquisition Data with simulated noise

# %%
num_angles = 400

angles = np.linspace(0, 180, num_angles, endpoint=False, dtype=np.float32)
ag2D = AcquisitionGeometry.create_Parallel2D()\
        .set_panel(num_pixels=N)\
        .set_angles(angles=angles)
ig2D = ag2D.get_ImageGeometry()
x_cil = ig2D.allocate()
x_cil.fill(gt)
A = ProjectionOperator(ig2D, ag2D, device="cpu")

# noiseless sinogram
noiseless = A.direct(x_cil)

## simulated noise
max_intensity = 2000
expected_counts = max_intensity * np.exp(-noiseless.array)
noisy_counts = np.random.poisson(expected_counts).astype(np.float32)
noisy_counts[noisy_counts == 0] = 1  # deal with 0s
y_np = -np.log(noisy_counts / max_intensity)
noisy = ag2D.allocate()
noisy.fill(y_np)

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 3, figsize=(12, 10), constrained_layout=True)

axs[0].imshow(gt)
axs[0].set_title("Ground Truth")

axs[1].imshow(noiseless.array)
axs[1].set_title("Noiseless Sinogram")

axs[2].imshow(noisy.array)
axs[2].set_title("Noisy Sinogram")

plt.show()

# %% [markdown]
# ### FBP reconstruction

# %%
fbp = FBP(ig2D, ag2D, device="cpu")(noisy)
fbp.array[fbp.array<0] = 0
plt.imshow(fbp.array)

# %% [markdown]
# ### Family of considered algorithms (ProxSkip template)
#
# **Parameters:** $\gamma>0$, probability $p\in(0,1]$, data subsets $N$
# **Initialize:** $x_0, h_0 \in \mathbb{R}^n$
#
# For $k=0,1,\dots,K-1$:
#
# 1. Compute $G_k$ (an unbiased estimator of $\nabla f(x_k)$).
# 2. $$\hat x_{k+1} = x_k - \gamma\big(G_k(x_k) - h_k\big).$$
# 3. Sample $\theta_k\sim\mathrm{Bernoulli}(p)$, $\theta_k\in{0,1}$.
# 4. If $\theta_k=1$:
#    $$x_{k+1}=\mathrm{prox}_{\frac{\gamma}{p}g}\left(\hat x_{k+1}-\frac{\gamma}{p}h_k\right),$$
#    else:
#    $$x_{k+1}=\hat x_{k+1}.$$
# 5. Update:
#    $$h_{k+1}=h_k+\frac{p}{\gamma}\big(x_{k+1}-\hat x_{k+1}\big).$$
#
# ---
#
# | $p=1$     | $0<p<1$       | $G_k$                                                                |
# | --------- | ------------- | -------------------------------------------------------------------- |
# | ISTA      | ProxSkip      | $\nabla f(x_k)$                                                      |
# | ProxSGD   | ProxSGDSkip   | $N\nabla f_{i_k}(x_k)$                                               |
# | ProxSAGA  | ProxSAGASkip  | $N(\nabla f_{i_k}(x_k)-v_k^{,i_k})+\bar v_k$                         |
# | ProxSVRG  | ProxSVRGSkip  | $N(\nabla f_{i_k}(x_k)-\nabla f_{i_k}(\tilde x))+\nabla f(\tilde x)$ |
# | ProxLSVRG | ProxLSVRGSkip | as above, updated with $p=1/N$                                       |
#
# *Note:* FISTA is ISTA with an acceleration step (Beck & Teboulle).

# %% [markdown]
# ### Define Stopping Criteria and Metrics (PSNR/SSIM)
#
# * We use **3 minutes** `time_stop` for locally on Mac (ARM, 16GB RAM).
# * For **Binder/GColab**, it’s better to use **5 minutes** due to limited memory.

# %%
gt_cil = ig2D.allocate()
gt_cil.fill(gt)

SSIM_ = lambda x, y: SSIM(x, y, data_range=x.max()-x.min())
PSNR_ = lambda x, y: PSNR(x, y, data_range=x.max()-x.min())

time_stop = 5*60 # 3 mins
max_iteration = 100_000

cb_metrics = MetricsDiagnostics(reference_image=gt_cil,
                         metrics_dict={"psnr":PSNR_,"ssim":SSIM_})

# %%
### Avoid computing objectives, not needed for this demo
def update_objective(self):
    return 0.

ISTA.update_objective = update_objective
ProxSkip.update_objective = update_objective
FISTA.update_objective = update_objective

# %% [markdown]
# ### Run deterministic algorithms: No data splitting, no skipping

# %%
sigma_no_skip = 0.0002
F = LeastSquares(A=A, b=noisy, c=0.5)

# %% [markdown]
# ### FISTA

# %%
initial = ig2D.allocate()
step_size = 1./F.L
G = BM3DFunction(sigma_no_skip)
cb_time = StoppingCriterionTime(time_stop)
fista = FISTA(initial = initial, f = F, step_size = step_size, g=G,
        update_objective_interval = 1,
        max_iteration = max_iteration)
fista.run(verbose=0, callback=[cb_metrics, cb_time])
# Out:
# Stop at 26 time 300.7682750225067

# %% [markdown]
# ### ISTA

# %%
G = BM3DFunction(sigma_no_skip)
cb_time = StoppingCriterionTime(time_stop)
ista = ISTA(initial = initial, f = F, step_size = step_size, g=G,
        update_objective_interval = 1,
        max_iteration = max_iteration)
ista.run(verbose=0, callback=[cb_metrics, cb_time])
# Out:
# Stop at 27 time 308.88228368759155

# %% [markdown]
# ### Run ProxSkip: Skip the regulariser

# %%
prob = 0.05
sigma_skip = sigma_no_skip/np.sqrt(prob)

# %%
G =  BM3DFunction(sigma_skip)

cb_time = StoppingCriterionTime(time_stop)
proxskip = ProxSkip(initial = [initial, initial], f = F, step_size = step_size, g=G,
        update_objective_interval = 1, prob=prob, seed = 42,
        max_iteration = max_iteration)
proxskip.run(verbose=0, callback=[cb_metrics, cb_time])
# Out:
# Stop at 205 time 300.071170091629

# %% [markdown]
# ### Run stochastic algorithms: Data splitting, no skipping

# %%
def list_of_functions(data):

    list_funcs = []
    ig = data[0].geometry.get_ImageGeometry()

    for d in data:
        ageom_subset = d.geometry
        Ai = ProjectionOperator(ig, ageom_subset, device = 'cpu')
        fi = LeastSquares(Ai, b = d, c = 0.5)
        list_funcs.append(fi)

    return list_funcs

# %%
# number of subsets
nsub = 50
data_split, method = noisy.split_to_subsets(nsub, method= "ordered", info=True)

# list of fis for finite sum
list_func = list_of_functions(data_split)
# Out:
# WARNING:root:Batch size is (constant) self.num_indices//self.num_batches

# %% [markdown]
# ### ProxSVRG and ProxSGD

# %%
selection = RandomSampling(len(list_func), nsub, seed=42)
Fsvrg = SVRGFunction(list_func, selection = selection, update_frequency=len(list_func))
Fsvrg.initial = initial
step_size = 1./(Fsvrg.L)

G =  BM3DFunction(sigma_no_skip)
cb_time = StoppingCriterionTime(time_stop)
prox_svrg = ISTA(initial = initial, f = Fsvrg, step_size = step_size, g=G,
            update_objective_interval = 1,
            max_iteration = max_iteration)
prox_svrg.run(verbose=0, callback=[cb_metrics, cb_time])
# Out:
# WARNING:root:Batch size is (constant) self.num_indices//self.num_batches
# Stop at 28 time 302.65859365463257

# %%
selection = RandomSampling(len(list_func), nsub, seed=42)
Fsgd = SGFunction(list_func, selection = selection)
step_size = 1./(Fsgd.L)

G =  BM3DFunction(sigma_no_skip)
cb_time = StoppingCriterionTime(time_stop)
prox_sgd = ISTA(initial = initial, f = Fsgd, step_size = step_size, g=G,
            update_objective_interval = 1,
            max_iteration = max_iteration)
prox_sgd.run(verbose=0, callback=[cb_metrics, cb_time])
# Out:
# WARNING:root:Batch size is (constant) self.num_indices//self.num_batches
# Stop at 29 time 304.8120746612549

# %% [markdown]
# ### Run stochastic algorithms: Data splitting and skipping

# %%
selection = RandomSampling(len(list_func), nsub, seed=42)
Fsvrg_skip = SVRGFunction(list_func, selection = selection, update_frequency=len(list_func))
Fsvrg_skip.initial = initial
step_size = 1./(Fsvrg_skip.L)

G =  BM3DFunction(sigma_skip)
cb_time = StoppingCriterionTime(time_stop)
prox_svrg_skip = ProxSkip(initial = [initial, initial], f = Fsvrg_skip, step_size = step_size, g=G,
            update_objective_interval = 1, prob=prob, seed=42,
            max_iteration = max_iteration)
prox_svrg_skip.run(verbose=0, callback=[cb_metrics, cb_time])
# Out:
# WARNING:root:Batch size is (constant) self.num_indices//self.num_batches
# Stop at 595 time 302.1395003795624

# %%
selection = RandomSampling(len(list_func), nsub, seed=42)
Fsgd_skip = SGFunction(list_func, selection = selection)
step_size = 1./(Fsgd_skip.L)

G =  BM3DFunction(sigma_skip)
cb_time = StoppingCriterionTime(time_stop)
prox_sgd_skip = ProxSkip(initial = [initial, initial], f = Fsgd_skip, step_size = step_size, g=G,
            update_objective_interval = 1, prob=prob, seed=42,
            max_iteration = max_iteration)
prox_sgd_skip.run(verbose=0, callback=[cb_metrics, cb_time])
# Out:
# WARNING:root:Batch size is (constant) self.num_indices//self.num_batches
# Stop at 635 time 304.81104803085327

# %% [markdown]
# ### Plot PSNR/SSIM progress
# - with respect to iteration
# - with respect to time

# %%
t_ista  = np.cumsum(ista.timing)
t_fista = np.cumsum(fista.timing)
t_proxskip    = np.cumsum(proxskip.timing)
t_prox_svrg  = np.cumsum(prox_svrg.timing)
t_prox_svrg_skip = np.cumsum(prox_svrg_skip.timing)
t_prox_sgd_skip   = np.cumsum(prox_sgd_skip.timing)

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['lines.linewidth'] = 5
plt.rcParams['lines.markersize'] = 20
plt.rcParams['font.size'] = 40

fig, ax = plt.subplots(2, 2, figsize=(35, 25), constrained_layout=True)

ax[0,0].plot(ista.psnr[:-1], label=f"ISTA, K={ista.iteration}, #BM3D={ista.iteration}")
ax[0,0].plot(fista.psnr[:-1], label=f"FISTA, K={fista.iteration}, #BM3D={fista.iteration}")
ax[0,0].plot(proxskip.psnr[:-1], label=f"ProxSkip, K={proxskip.iteration},  #BM3D={np.sum(proxskip.thetas)}")
ax[0,0].plot(prox_svrg.psnr[:-1], label=f"ProxSVRG, K={prox_svrg.iteration}, #BM3D={prox_svrg.iteration}")
ax[0,0].plot(prox_sgd_skip.psnr[:-1],label=f"ProxSGDSkip, K={prox_svrg_skip.iteration}, #BM3D={np.sum(prox_svrg_skip.thetas)}", alpha=0.65)
ax[0,0].plot(prox_svrg_skip.psnr[:-1],label=f"ProxSVRGSkip, K={prox_svrg_skip.iteration}, #BM3D={np.sum(prox_svrg_skip.thetas)}")
ax[0,0].grid(which="major")
ax[0,0].set_xlabel("Iteration")
ax[0,0].set_ylabel("PSNR")

ax[0,1].plot(ista.ssim[:-1], label=f"ISTA, K={ista.iteration}, #BM3D={ista.iteration}")
ax[0,1].plot(fista.ssim[:-1], label=f"FISTA, K={fista.iteration}, #BM3D={fista.iteration}")
ax[0,1].plot(proxskip.ssim[:-1], label=f"ProxSkip, p={prob}, #prox={np.sum(proxskip.thetas)}")
ax[0,1].plot(prox_svrg.ssim[:-1], label="ProxSVRG")
ax[0,1].semilogy(prox_sgd_skip.ssim[:-1],label=f"ProxSGDSkip, K={prox_svrg_skip.iteration}, N={nsub}, p={prob}, #BM3D={np.sum(prox_svrg_skip.thetas)}", alpha=0.65)
ax[0,1].plot(prox_svrg_skip.ssim[:-1],label=f"ProxSVRGSkip, p={prob}, #prox={np.sum(prox_svrg_skip.thetas)}")
ax[0,1].grid(which="major")
ax[0,1].set_xlabel("Iteration")
ax[0,1].set_ylabel("SSIM")

ax[1,0].plot(t_ista,  ista.psnr[:-1], label=f"ISTA, K={ista.iteration}, #BM3D={ista.iteration}")
ax[1,0].plot(t_fista, fista.psnr[:-1], label=f"FISTA, K={fista.iteration}, #BM3D={fista.iteration}")
ax[1,0].plot(t_proxskip,    proxskip.psnr[:-1], label=f"ProxSkip, K={proxskip.iteration},  #BM3D={np.sum(proxskip.thetas)}")
ax[1,0].plot(t_prox_svrg,  prox_svrg.psnr[:-1], label=f"ProxSVRG, K={prox_svrg.iteration}, #BM3D={prox_svrg.iteration}")
ax[1,0].plot(t_prox_sgd_skip, prox_sgd_skip.psnr[:-1],
               label=f"ProxSGDSkip, K={prox_svrg_skip.iteration}, #BM3D={np.sum(prox_svrg_skip.thetas)}", alpha=0.65)
ax[1,0].plot(t_prox_svrg_skip, prox_svrg_skip.psnr[:-1],
               label=f"ProxSVRGSkip, K={prox_svrg_skip.iteration}, #BM3D={np.sum(prox_svrg_skip.thetas)}")
ax[1,0].grid(which="major")
ax[1,0].set_xlabel("Time (sec)")
ax[1,0].set_ylabel("PSNR")

ax[1,1].plot(t_ista,  ista.ssim[:-1], label=f"ISTA, K={ista.iteration}, #BM3D={ista.iteration}")
ax[1,1].plot(t_fista, fista.ssim[:-1], label=f"FISTA, K={fista.iteration}, #BM3D={fista.iteration}")
ax[1,1].plot(t_proxskip,    proxskip.ssim[:-1], label=f"ProxSkip, p={prob}, #prox={np.sum(proxskip.thetas)}")
ax[1,1].plot(t_prox_svrg,  prox_svrg.ssim[:-1], label="ProxSVRG")
ax[1,1].semilogy(t_prox_sgd_skip, prox_sgd_skip.ssim[:-1],
               label=f"ProxSGDSkip, K={prox_svrg_skip.iteration}, N={nsub}, p={prob}, #BM3D={np.sum(prox_svrg_skip.thetas)}", alpha=0.65)
ax[1,1].plot(t_prox_svrg_skip, prox_svrg_skip.ssim[:-1],
           label=f"ProxSVRGSkip, p={prob}, #prox={np.sum(prox_svrg_skip.thetas)}")
ax[1,1].grid(which="major")
ax[1,1].set_xlabel("Time (sec)")
ax[1,1].set_ylabel("SSIM")

handles, labels = ax[0,1].get_legend_handles_labels()
fig.legend(handles, labels, loc="upper center", bbox_to_anchor=(0.53, 1.14),
           ncols=2, frameon=True)


plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from matplotlib.patches import Rectangle

imgs = [
    x_cil.array,
    fbp.array,
    ista.solution.array,
    fista.solution.array,
    proxskip.solution.array,
    prox_svrg.solution.array,
    prox_sgd_skip.solution.array,
    prox_svrg_skip.solution.array,
]

labels = [
    "Ground-Truth",
    f"FBP",
    f"ISTA\nPSNR/SSIM = {ista.psnr[-1]:.2f}/{ista.ssim[-1]:.3f}",
    f"FISTA\nPSNR/SSIM = {fista.psnr[-1]:.2f}/{fista.ssim[-1]:.3f}",
    f"ProxSkip\nPSNR/SSIM = {proxskip.psnr[-1]:.2f}/{proxskip.ssim[-1]:.3f}",
    f"ProxSVRG\nPSNR/SSIM = {prox_svrg.psnr[-1]:.2f}/{prox_svrg.ssim[-1]:.3f}",
    f"ProxSGDSkip\nPSNR/SSIM = {prox_sgd_skip.psnr[-1]:.2f}/{prox_sgd_skip.ssim[-1]:.3f}",
    f"ProxSVRGSkip\nPSNR/SSIM = {prox_svrg_skip.psnr[-1]:.2f}/{prox_svrg_skip.ssim[-1]:.3f}",
]

vmax = max(np.max(im) for im in imgs)
vmin = 0.01
vmax = 0.03

h, w = imgs[0].shape[:2]
img_aspect = w / h
nrows, ncols = 2, 4

fig_h = 15
fig_w = fig_h * (ncols / nrows) * img_aspect

fig = plt.figure(figsize=(fig_w, fig_h))
gs = fig.add_gridspec(nrows, ncols, wspace=0, hspace=0)
axes = np.array([fig.add_subplot(gs[i, j]) for i in range(nrows) for j in range(ncols)])
fig.subplots_adjust(left=0, right=1, bottom=0, top=1)

H, W = imgs[0].shape[:2]
roi_size = 80
cx, cy = 75, 120

x0 = cx - roi_size // 2
x1 = x0 + roi_size
y0 = cy - roi_size // 2
y1 = y0 + roi_size

x0 = max(0, min(x0, W - roi_size)); x1 = x0 + roi_size
y0 = max(0, min(y0, H - roi_size)); y1 = y0 + roi_size

inset_size = "32%"
inset_borderpad = 0.6

for ax, im, txt in zip(axes, imgs, labels):
    ax.imshow(im, cmap="inferno", vmin=vmin, vmax=vmax)
    ax.axis("off")

    ax.text(
        0.02, 0.98, txt,
        transform=ax.transAxes,
        ha="left", va="top",
        color="white", fontsize=32,
        bbox=dict(boxstyle="round,pad=0.3", facecolor="black", alpha=0.25, edgecolor="none")
    )

    rect = Rectangle((x0, y0), roi_size, roi_size,
                     linewidth=2.5, edgecolor="yellow", facecolor="none")
    ax.add_patch(rect)

    axins = inset_axes(ax, width=inset_size, height=inset_size,
                       loc="lower right", borderpad=inset_borderpad)
    axins.imshow(im, cmap="inferno", vmin=vmin, vmax=vmax)
    axins.set_xlim(x0, x1)
    axins.set_ylim(y1, y0)
    axins.set_xticks([])
    axins.set_yticks([])
    for spine in axins.spines.values():
        spine.set_linewidth(2)
        spine.set_edgecolor("yellow")

plt.show()
